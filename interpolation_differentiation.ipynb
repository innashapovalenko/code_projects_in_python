# %% [markdown]
# Data interpolation, Langrange interpolation polynomial, Numerical Differentiation

# %% [markdown]
# Calculation of an interpolating polynomial of cubic degree

# %%
list_elem = []
result_list = []

for x in list_elem:
    '''x0 = 
    x1 =
    x2 = 
    x3 = 

    y0 = 
    y1 = 
    y2 = 
    y3 = '''

    l_0 = y0 * ((x - x1) * (x - x2) * (x - x3)) / ((x0 - x1) * (x0 - x2) * (x0 - x3)) 
    l_1 = y1 * ((x - x0) * (x - x2) * (x - x3)) / ((x1 - x0) * (x1 - x2) * (x1 - x3)) 
    l_2 = y2 * ((x - x0) * (x - x1) * (x - x3)) / ((x2 - x0) * (x2 - x1) * (x2 - x3))
    l_3 = y3 * ((x - x0) * (x - x1) * (x - x2)) / ((x3 - x0) * (x3 - x1) * (x3 - x2))
 

    L = l_0 + l_1 + l_2 + l_3 
    x = L
    result_list.append(x)
    
print(result_list)
# Out:
# []

# %% [markdown]
# Calculation of values ​​directly according to the formula

# %%
import math

#знаходимо значення з кроком 0.01 на відрізку від а до в
a = 0
b = 1.5
i = 0
h = 0.01
list_elem = []
while i <= b:
    i = i + h
    list_elem.append(i)


#підставляємо отримані значення в функцію
funct_list = []
for elem in list_elem:
    elem = 3**elem + math.sin(elem)
    funct_list.append(elem)
    
    
#print(funct_list)

# %% [markdown]
# Calculation of values ​​with the help of piecewise interpolation by cubic Langrange polynomials

# %%
a = 0
b = 1.5
h = 0.01
list_elem = []
i = 0
while i <= b:
    i = i + h
    list_elem.append(i)
    
list_results = []
for x in list_elem:
    negat_number = -0.11
    list_xy = [(-0.11, 0.7764), (0.11, 1.2382), (0.24, 1.5394), (0.36, 1.8374), (0.57, 2.4101), (0.66, 2.6780), (0.89, 3.4356), (1.1, 4.2396), (1.39, 5.5884), (1.6, 6.7991)]
    list_x = [-0.11, 0.11, 0.24, 0.36, 0.57, 0.66, 0.89, 1.1, 1.39, 1.6]
    list_wish_x = []
   
     
    for elem_x in list_x:
        elem_x =  x - elem_x
        elem_x = abs(elem_x)
        list_wish_x.append(elem_x)
         
         
    dict_x = dict(zip(list_xy, list_wish_x))

     
    sorted_dict_x = sorted(dict_x.items(), key = lambda item: item[1])
     
 
    x_0 = sorted_dict_x[0]
    x_0 = list(x_0)
    x_0 = x_0[0]
    x_0 = list(x_0)
    x_0 = x_0[0]
    x_0 = float(x_0)

    x_1 = sorted_dict_x[1]
    x_1 = list(x_1)
    x_1 = x_1[0]
    x_1 = list(x_1)
    x_1 = x_1[0]
  
    x_2 = sorted_dict_x[2]
    x_2 = list(x_2)
    x_2 = x_2[0]
    x_2 = list(x_2)
    x_2 = x_2[0]
     
    x_3 = sorted_dict_x[3]
    x_3 = list(x_3)
    x_3= x_3[0]
    x_3 = list(x_3)
    x_3= x_3[0]
     
    y_0 = sorted_dict_x[0]
    y_0 = list(y_0)
    y_0 = y_0[0]
    y_0 = list(y_0)
    y_0 = y_0[1]
    
    
    y_1 = sorted_dict_x[1]
    y_1 = list(y_1)
    y_1 = y_1[0]
    y_1 = list(y_1)
    y_1 = y_1[1]
     
    y_2 = sorted_dict_x[2]
    y_2 = list(y_2)
    y_2 = y_2[0]
    y_2 = list(y_2)
    y_2 = y_2[1]
     
    y_3 = sorted_dict_x[3]
    y_3 = list(y_3)
    y_3= y_3[0]
    y_3 = list(y_3)
    y_3= y_3[1]
     

    
    l_0 = (y_0 * (x - x_1) * (x - x_2) * (x - x_3)) / ((x_0 - x_1) * (x_0 - x_2) * (x_0 - x_3))
    l_1 = (y_1 * (x - x_0) * (x - x_2) * (x - x_3)) / ((x_1 - x_0) * (x_1 - x_2) * (x_1 - x_3))
    l_2 = (y_2 * (x - x_0) * (x - x_1) * (x - x_3)) / ((x_2 - x_0) * (x_2 - x_1) * (x_2 - x_3))
    l_3 = (y_3 * (x - x_0) * (x - x_1) * (x - x_2)) / ((x_3 - x_0) * (x_3 - x_1) * (x_3 - x_2))
     
    L = l_0 + l_1 + l_2 + l_3
     
    list_results.append(L)

#print(list_results)

# %% [markdown]
# Calculation of values ​​using global interpolation with Langrange polynomials

# %%
a = 0
b = 1.5
h = 0.01
i = 0
list_elem = []
while i <= b:
    i = i + h
    list_elem.append(i)

fuct_list = []

for x in list_elem:
    x0 = -0.11
    x1 = 0.11
    x2 = 0.24
    x3 = 0.36
    x4 = 0.57
    x5 = 0.66
    x6 = 0.89
    x7 = 1.1
    x8 = 1.39
    x9 = 1.6

    y0 = 0.7764
    y1 = 1.2382
    y2 = 1.5394
    y3 = 1.8374
    y4 = 2.4101
    y5 = 2.6780
    y6 = 3.4356
    y7 = 4.2396
    y8 = 5.5884
    y9 = 6.771
    l0 = y0 * ((x - x1) * (x - x2) * (x - x3) * (x - x4) * (x - x5) * (x - x6) * (x - x7) * (x - x8) * (x - x9)) / ((x0 - x1) * (x0 - x2) * (x0 - x3) * (x0 - x4) * (x0 - x5) * (x0 - x6) * (x0 - x7) * (x0 - x8) * (x0 - x9))
    l1 = y1 * ((x - x0) * (x - x2) * (x - x3) * (x - x4) * (x - x5) * (x - x6) * (x - x7) * (x - x8) * (x - x9)) / ((x1 - x0) * (x1 - x2) * (x1 - x3) * (x1 - x4) * (x1 - x5) * (x1 - x6) * (x1 - x7) * (x1 - x8) * (x1 - x9))
    l2 = y2 * ((x - x0) * (x - x1) * (x - x3) * (x - x4) * (x - x5) * (x - x6) * (x - x7) * (x - x8) * (x - x9)) / ((x2 - x0) * (x2 - x1) * (x2 - x3) * (x2 - x4) * (x2 - x5) * (x2 - x6) * (x2 - x7) * (x2 - x8) * (x2 - x9))
    l3 = y3 * ((x - x0) * (x - x1) * (x - x2) * (x - x4) * (x - x5) * (x - x6) * (x - x7) * (x - x8) * (x - x9)) / ((x3 - x0) * (x3 - x1) * (x3 - x2) * (x3 - x4) * (x3 - x5) * (x3 - x6) * (x3 - x7) * (x3 - x8) * (x3 - x9))
    l4 = y4 * ((x - x0) * (x - x1) * (x - x2) * (x - x3) * (x - x5) * (x - x6) * (x - x7) * (x - x8) * (x - x9)) / ((x4 - x0) * (x4 - x1) * (x4 - x2) * (x4 - x3) * (x4 - x5) * (x4 - x6) * (x4 - x7) * (x4 - x8) * (x4 - x9))
    l5 = y5 * ((x - x0) * (x - x1) * (x - x2) * (x - x3) * (x - x4) * (x - x6) * (x - x7) * (x - x8) * (x - x9)) / ((x5 - x0) * (x5 - x1) * (x5 - x2) * (x5 - x3) * (x5 - x4) * (x5 - x6) * (x5 - x7) * (x5 - x8) * (x5 - x9))
    l6 = y6 * ((x - x0) * (x - x1) * (x - x2) * (x - x3) * (x - x4) * (x - x5) * (x - x7) * (x - x8) * (x - x9)) / ((x6 - x0) * (x6 - x1) * (x6 - x2) * (x6 - x3) * (x6 - x4) * (x6 - x5) * (x6 - x7) * (x6 - x8) * (x6 - x9))
    l7 = y7 * ((x - x0) * (x - x1) * (x - x2) * (x - x3) * (x - x4) * (x - x5) * (x - x6) * (x - x8) * (x - x9)) / ((x7 - x0) * (x7 - x1) * (x7 - x2) * (x7 - x3) * (x7 - x4) * (x7 - x5) * (x7 - x6) * (x7 - x8) * (x7 - x9))
    l8 = y8 * ((x - x0) * (x - x1) * (x - x2) * (x - x3) * (x - x4) * (x - x5) * (x - x6) * (x - x7) * (x - x9)) / ((x8 - x0) * (x8 - x1) * (x8 - x2) * (x8 - x3) * (x8 - x4) * (x8 - x5) * (x8 - x6) * (x8 - x7) * (x8 - x9))
    l9 = y9 * ((x - x0) * (x - x1) * (x - x2) * (x - x3) * (x - x4) * (x - x5) * (x - x6) * (x - x7) * (x - x8)) / ((x9 - x0) * (x9 - x1) * (x9 - x2) * (x9 - x3) * (x9 - x4) * (x9 - x5) * (x9 - x6) * (x9 - x7) * (x9 - x8))

    L = l0 + l1 + l2 + l3 + l4 + l5 + l6 + l7 + l8 + l9
    x = L
    funct_list.append(x)
   
    
#print(funct_list)

# %% [markdown]
# Calculation of values ​​using direct differentiation of f'

# %%
import math

#find the value with a step of 0.01 on the segment from a to c
a = 0
b = 1.5
i = 0
h = 0.01
list_elem = []
while i <= b:
    i = i + h
    list_elem.append(i)

#знаходимо першу похідну
list_f = []
for x in list_elem:
    x = (3 ** x) * math.log(3) + math.cos(x)
    list_f.append(x)
   
    
#print(list_f)

# %% [markdown]
# Calculation of values ​​using direct differentiation of f"

# %%
import math

#знаходимо значення з кроком 0.01 на відрізку від а до в
a = 0
b = 1.5
i = 0
h = 0.01
list_elem = []
while i <= b:
    i = i + h
    list_elem.append(i)

#знаходимо другу похідну
list_f = []
for x in list_elem:
    x = (3 ** x) * (math.log(3) ** 2) - math.sin(x)
    list_f.append(x)

    
#print(list_f)

# %% [markdown]
# Calculation of values ​​using numerical differentiation of f' on the segment [0; 1.5], h = 0.01

# %%
list_L = [1.0210764350543067, 1.0422369361702126, 1.063518599018003, 1.0849219758964435, 1.1064476191042998, 1.1280960809403362, 1.1498679137033179, 1.1717636696920093, 1.1937839012051776, 1.215929160541586, 1.2381999999999995, 1.2605969718791845, 1.2831206284779053, 1.3057715220949262, 1.3285502050290134, 1.3514572295789318, 1.374493148043446, 1.3976585127213212, 1.4209538759113232, 1.4443797899122155, 1.4679368070227645, 1.4916254795417354, 1.5154568161114248, 1.5394, 1.5634766302489784, 1.5876876613241833, 1.6120340476914392, 1.6365167438165704, 1.6611367041654002, 1.6858948832037535, 1.7107922353974532, 1.7358297152123243, 1.7610082771141904, 1.7863288755688762, 1.8117924650422046, 1.8374000000000004, 1.8631524349080875, 1.88905072423229, 1.9150454545454554, 1.94122102934103, 1.9675456950456955, 1.99402077922078, 2.020647609427611, 2.0474275132275137, 2.0743618181818184, 2.1014518518518526, 2.128698941798943, 2.1561044155844162, 2.1836696007696013, 2.2113958249158254, 2.2392844155844167, 2.2673367003367013, 2.2955540067340077, 2.3239376623376637, 2.3524889947089958, 2.3812093314093317, 2.4101000000000012, 2.439148254358895, 2.468371894654089, 2.4977727282315727, 2.5273525624373354, 2.5571132046173695, 2.5870564621176615, 2.6171841422842044, 2.6474980524629874, 2.6780000000000004, 2.7086917922412344, 2.739575236532679, 2.7706521402203212, 2.801924310650156, 2.8333935551681715, 2.865061681120357, 2.8967138029184385, 2.928755125022641, 2.9610031690469096, 2.993460467871616, 3.026129554377126, 3.059012961443808, 3.092113221952031, 3.125432868782163, 3.1589744348145716, 3.1927404529296255, 3.226733456007694, 3.260955976929144, 3.2954105485743423, 3.3300997038236595, 3.3650259755574634, 3.400191896656121, 3.4356000000000018, 3.4712528184694738, 3.5071528849449036, 3.5433027323066626, 3.5797048934351157, 3.616361901210632, 3.65327628851358, 3.690450588224329, 3.727887333223246, 3.765013247479802, 3.802953491316966, 3.8411744422113827, 3.8796796327116674, 3.918472595366435, 3.957556862724306, 3.996935967333895, 4.036613441743817, 4.0765928185026885, 4.116877630159126, 4.157471409261748, 4.198377688359168, 4.239600000000003, 4.28114187673287, 4.323006851106385, 4.364762193020194, 4.407137607252714, 4.449848581142028, 4.492900045514469, 4.536296931196377, 4.580044169014089, 4.62414668979394, 4.668609424362271, 4.7134373035454145, 4.758635258169712, 4.8042082190615005, 4.850161117047113, 4.896498882952893, 4.943226447605176, 4.990348741830298, 5.037870696454594, 5.085797242304405, 5.134133310206068, 5.18288383098592, 5.232053735470298, 5.28164795448554, 5.331671418857982, 5.382129059413962, 5.433025806979815, 5.484366592381884, 5.536156346446501, 5.588400000000006, 5.641102483868736, 5.694268728879027, 5.747903665857218, 5.802012225629647, 5.856599339022648, 5.911669936862561, 5.9672289499757225, 6.02328130918847, 6.079831945327142, 6.136885789218074, 6.194447771687604]

length = len(list_L)
list_L3 = list_L * 3
h = 0.01

list_result = []
for n, a, b in zip(list_L, list_L3[length-1:], list_L3[length+1:]):
    if n == list_L3[0]:
        df1 = (b - n) / h #n - current element, b - next element, a - previous
        list_result.append(df1)
    elif n == list_L3[-1]:
        dfn = (n - a) / h
        list_result.append(dfn)
    else:
        dfi = (b - a) / (2 * h)
        list_result.append(dfi)

#print(list_result)

# %% [markdown]
# Calculation of values ​​using numerical differentiation of f" on the segment [0; 1.5], h = 0.01

# %%
